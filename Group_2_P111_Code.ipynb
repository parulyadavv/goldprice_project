# %% [markdown]
# ## Gold Price Prediction: Project P111
# * Mentors: KARTIK and DHANYAPRIYA
# * _Team Members_:
# ** Gourangee S Dhanagare
# ** Rahul Chauhan
# ** Arman N Soni
# ** Parul yadav
# ** Nirali Raval
# ** Prathik Mohan

# %% [markdown]
# ### Importing Libraries

# %%
#import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from pandas import DataFrame
from pandas import Grouper
import calplot
import calmap
import calendar
import seaborn as sns
import itertools
import warnings
warnings.filterwarnings("ignore")
from scipy import stats
plt.style.use('fivethirtyeight')
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from math import sqrt
from statsmodels.tsa.api import ExponentialSmoothing
from pandas import read_csv
from statsmodels.graphics.tsaplots import plot_acf
from pylab import rcParams
# %matplotlib inline

# %%
#import the given dataset as a series object for time series analysis
series = pd.read_csv(r'C:\Users\prathikm\Documents\P111\Gold_data.csv',index_col=0, parse_dates=True)#, header=0, index_col=0, parse_dates=True, squeeze=True)
series
# Out:
#               price
# date
# 2016-01-01  2252.60
# 2016-01-02  2454.50
# 2016-01-03  2708.10
# 2016-01-04  2577.80
# 2016-01-05  2597.75
# ...             ...
# 2021-12-17  4394.40
# 2021-12-18  4389.50
# 2021-12-19  4389.50
# 2021-12-20  4354.10
# 2021-12-21  4346.50
#
# [2182 rows x 1 columns]

# %%
#converting date to date-time
series.columns=["price"]
series.index=pd.to_datetime(series.index)
series
# Out:
#               price
# date
# 2016-01-01  2252.60
# 2016-01-02  2454.50
# 2016-01-03  2708.10
# 2016-01-04  2577.80
# 2016-01-05  2597.75
# ...             ...
# 2021-12-17  4394.40
# 2021-12-18  4389.50
# 2021-12-19  4389.50
# 2021-12-20  4354.10
# 2021-12-21  4346.50
#
# [2182 rows x 1 columns]

# %%
series_2 = series.copy()

# %% [markdown]
# ### Train-Test Split

# %%
#Doing 80:20 Split
Train=series.iloc[:1745,:]
Test=series.iloc[1745:,]

# %% [markdown]
# ### Initial Exploration (EDA) of RAW Data

# %%
#descriptive statistics to know more about the raw data
series.describe()
# Out:
#              price
# count  2182.000000
# mean   3284.450046
# std     719.564434
# min    2252.600000
# 25%    2697.020000
# 50%    2879.800000
# 75%    4147.325000
# max    4966.300000

# %%
#how many observations
series.size
# Out:
# 2182

# %%
#check january 2016 data - COMPLETE data is present for each day including holidays
series['2016-01']
# Out:
#                   price
# date
# 2016-01-01  2252.600000
# 2016-01-02  2454.500000
# 2016-01-03  2708.100000
# 2016-01-04  2577.800000
# 2016-01-05  2597.750000
# 2016-01-06  2617.700000
# 2016-01-07  2903.800000
# 2016-01-08  2887.800000
# 2016-01-09  2813.800000
# 2016-01-10  2786.800000
# 2016-01-11  2759.800000
# 2016-01-12  2549.000000
# 2016-01-13  2335.600000
# 2016-01-14  2332.000000
# 2016-01-15  2365.800000
# 2016-01-16  2367.066667
# 2016-01-17  2368.333333
# 2016-01-18  2369.600000
# 2016-01-19  2359.400000
# 2016-01-20  2394.100000
# 2016-01-21  2395.600000
# 2016-01-22  2390.300000
# 2016-01-23  2393.333333
# 2016-01-24  2396.366667
# 2016-01-25  2399.400000
# 2016-01-26  2420.900000
# 2016-01-27  2428.800000
# 2016-01-28  2431.200000
# 2016-01-29  2430.200000
# 2016-01-30  2437.850000
# 2016-01-31  2445.500000

# %%
series['2017-05'].head(8) #random may 2017
# Out:
#              price
# date
# 2017-05-01  2559.4
# 2017-05-02  2573.2
# 2017-05-03  2587.0
# 2017-05-04  2600.8
# 2017-05-05  2532.4
# 2017-05-06  2643.5
# 2017-05-07  2538.3
# 2017-05-08  2643.3

# %%
series['2021-12'] #last month only 21 days
# Out:
#              price
# date
# 2021-12-01  4353.2
# 2021-12-02  4238.1
# 2021-12-03  4017.1
# 2021-12-04  4170.4
# 2021-12-05  4305.5
# 2021-12-06  4413.6
# 2021-12-07  4319.4
# 2021-12-08  4181.5
# 2021-12-09  4219.4
# 2021-12-10  4264.7
# 2021-12-11  4448.9
# 2021-12-12  4333.5
# 2021-12-13  4351.4
# 2021-12-14  4328.2
# 2021-12-15  4348.7
# 2021-12-16  4399.8
# 2021-12-17  4394.4
# 2021-12-18  4389.5
# 2021-12-19  4389.5
# 2021-12-20  4354.1
# 2021-12-21  4346.5

# %%
#reading as data frame
df = pd.read_csv("Gold_data.csv")
df
# Out:
#             date    price
# 0     2016-01-01  2252.60
# 1     2016-01-02  2454.50
# 2     2016-01-03  2708.10
# 3     2016-01-04  2577.80
# 4     2016-01-05  2597.75
# ...          ...      ...
# 2177  2021-12-17  4394.40
# 2178  2021-12-18  4389.50
# 2179  2021-12-19  4389.50
# 2180  2021-12-20  4354.10
# 2181  2021-12-21  4346.50
#
# [2182 rows x 2 columns]

# %%
#checking the data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2182 entries, 0 to 2181
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2182 non-null   object
#  1   price   2182 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 34.2+ KB

# %%
#converting object to date time
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2182 entries, 0 to 2181
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2182 non-null   datetime64[ns]
#  1   price   2182 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 34.2 KB

# %%
################# GOLD PRICE FROM BEGINNING ################

# build the frame
fig,ax = plt.subplots(figsize=(25,10))

date = df['date']
value = df['price']

# give the title, x and y axis names
plt.title("Gold Price 1st January 2016 to 31st December 2021",fontsize=18)
plt.xlabel("Time Frame",fontsize=13)
plt.ylabel("Gold Price",fontsize=13)

# display formatting
year_month_separator = mdates.MonthLocator()
year_month_formatter = mdates.DateFormatter("%b-%y")

ax.xaxis.set_major_locator(year_month_separator)
ax.xaxis.set_major_formatter(year_month_formatter)

ax.plot(date,value);

# auto format tilt the x-axis labels
fig.autofmt_xdate()

# %%
df = df.set_index(['date'])
df
# Out:
#               price
# date
# 2016-01-01  2252.60
# 2016-01-02  2454.50
# 2016-01-03  2708.10
# 2016-01-04  2577.80
# 2016-01-05  2597.75
# ...             ...
# 2021-12-17  4394.40
# 2021-12-18  4389.50
# 2021-12-19  4389.50
# 2021-12-20  4354.10
# 2021-12-21  4346.50
#
# [2182 rows x 1 columns]

# %%
################ YEARLY SEASONAL PRICE #####################
calmap.calendarplot(df['price'], fillcolor='black',fig_kws=dict(figsize=(20, 15)))
# Out:
# (<Figure size 1440x1080 with 6 Axes>,
#  array([<AxesSubplot:ylabel='2016'>, <AxesSubplot:ylabel='2017'>,
#         <AxesSubplot:ylabel='2018'>, <AxesSubplot:ylabel='2019'>,
#         <AxesSubplot:ylabel='2020'>, <AxesSubplot:ylabel='2021'>],
#        dtype=object))

# %%
df_2 = df.reset_index()
df_2
# Out:
#            date    price
# 0    2016-01-01  2252.60
# 1    2016-01-02  2454.50
# 2    2016-01-03  2708.10
# 3    2016-01-04  2577.80
# 4    2016-01-05  2597.75
# ...         ...      ...
# 2177 2021-12-17  4394.40
# 2178 2021-12-18  4389.50
# 2179 2021-12-19  4389.50
# 2180 2021-12-20  4354.10
# 2181 2021-12-21  4346.50
#
# [2182 rows x 2 columns]

# %%
################ AVERAGE PRICE EVERY MONTH #####################

#Spliting the dates
df_2['Day'] = df_2['date'].dt.day
df_2['Month'] = df_2['date'].dt.month
df_2['Year'] = df_2['date'].dt.year
df_2
# Out:
#            date    price  Day  Month  Year
# 0    2016-01-01  2252.60    1      1  2016
# 1    2016-01-02  2454.50    2      1  2016
# 2    2016-01-03  2708.10    3      1  2016
# 3    2016-01-04  2577.80    4      1  2016
# 4    2016-01-05  2597.75    5      1  2016
# ...         ...      ...  ...    ...   ...
# 2177 2021-12-17  4394.40   17     12  2021
# 2178 2021-12-18  4389.50   18     12  2021
# 2179 2021-12-19  4389.50   19     12  2021
# 2180 2021-12-20  4354.10   20     12  2021
# 2181 2021-12-21  4346.50   21     12  2021
#
# [2182 rows x 5 columns]

# %%
#  Generating the avgerage open gold price
all_month_year_df = pd.pivot_table(df_2, values="price",
                                   index=["Month"],
                                   columns=["Year"],
                                   fill_value=0,
                                   margins=True)
# Setting the index (month names)
named_index = [[calendar.month_abbr[i] if isinstance(i, int) else i for i in list(all_month_year_df.index)]]
all_month_year_df = all_month_year_df.set_index(named_index)
all_month_year_df
# Out:
# Year         2016         2017         2018         2019         2020  \
# Jan   2495.832258  2626.077957  2748.438710  3015.954839  3803.264516
# Feb   2688.703448  2646.730357  2766.942857  3068.482143  3903.472414
# Mar   2682.854839  2597.485484  2766.806452  2989.967742  3915.170968
# Apr   2677.790000  2620.758333  2806.903333  2970.890000  4187.580000
# May   2677.650000  2605.872581  2806.258065  2978.335484  4208.000000
# Jun   2745.596667  2607.733333  2781.715000  3098.686667  4250.550000
# Jul   2779.582258  2599.256452  2739.325806  3136.961290  4393.832258
# Aug   2792.240323  2642.133871  2722.327419  3351.954839  4491.829032
# Sep   2792.705000  2669.835000  2777.303333  3310.843333  4399.250000
# Oct   2720.454839  2648.345161  2851.996774  3300.645161  4388.651613
# Nov   2674.280000  2646.371667  2789.446667  3274.526667  4312.750000
# Dec   2563.683333  2612.683871  2825.232258  3299.116129  4331.187097
# All   2690.614162  2626.676484  2781.938082  3150.210685  4216.378689
#
# Year         2021          All
# Jan   4305.209677  3165.796326
# Feb   4208.853571  3214.831471
# Mar   4118.264516  3178.425000
# Apr   4259.273333  3253.865833
# May   4346.348387  3270.410753
# Jun   4262.783333  3291.177500
# Jul   4308.632258  3326.265054
# Aug   4264.919355  3377.567473
# Sep   4207.506667  3359.573889
# Oct   4289.148387  3366.540323
# Nov   4327.633333  3337.501389
# Dec   4312.733333  3267.933996
# All   4266.871549  3284.450046

# %%
type(all_month_year_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#converting float to integers
all_month_year_df_2 = all_month_year_df.astype(int)
all_month_year_df_2
# Out:
# Year  2016  2017  2018  2019  2020  2021   All
# Jan   2495  2626  2748  3015  3803  4305  3165
# Feb   2688  2646  2766  3068  3903  4208  3214
# Mar   2682  2597  2766  2989  3915  4118  3178
# Apr   2677  2620  2806  2970  4187  4259  3253
# May   2677  2605  2806  2978  4208  4346  3270
# Jun   2745  2607  2781  3098  4250  4262  3291
# Jul   2779  2599  2739  3136  4393  4308  3326
# Aug   2792  2642  2722  3351  4491  4264  3377
# Sep   2792  2669  2777  3310  4399  4207  3359
# Oct   2720  2648  2851  3300  4388  4289  3366
# Nov   2674  2646  2789  3274  4312  4327  3337
# Dec   2563  2612  2825  3299  4331  4312  3267
# All   2690  2626  2781  3150  4216  4266  3284

# %%
# plot of average gold price for all months
ax = sns.heatmap(all_month_year_df_2, cmap='RdYlGn_r', robust=True, fmt='.2f', 
                 annot=True, linewidths=.5, annot_kws={'size':8}, 
                 cbar_kws={'shrink':.8, 'label':'Open'})                       
    
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=10)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=10)
plt.title('Average Gold Price', fontdict={'fontsize':18},    pad=14);

# %%
series.hist() #histogram plot
# Out:
# array([[<AxesSubplot:title={'center':'price'}>]], dtype=object)

# %%
series.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Pre-processing Data for Model Building

# %%
#auto correlation plot
plot_acf(series, lags=10)
plt.show()

# %%
# overall plot for years
series.plot(figsize=(15,6))
plt.show()

# %%
#split series into years to show decomposition
series_jan_2016 = series['2016-01']#:'2017-01']
series_jan_2017 = series['2017-01']
series_jan_2018 = series['2018-01']
series_jan_2019 = series['2019-01']
series_jan_2020 = series['2020-01']
series_jan_2021 = series['2021-01']

# %%
#decomposing time series
rcParams['figure.figsize'] = 18, 8

print("\n")
print("*************************************************************************************ANALYSIS FOR 2016**************************************************************************")
print()
decomposition = sm.tsa.seasonal_decompose(series_jan_2016)
fig = decomposition.plot()
plt.show()

print("\n")
print("*************************************************************************************ANALYSIS FOR 2017**************************************************************************")
print()
decomposition = sm.tsa.seasonal_decompose(series_jan_2017)
fig = decomposition.plot()
plt.show()

print("\n")
print("*************************************************************************************ANALYSIS FOR 2018**************************************************************************")
print()
decomposition = sm.tsa.seasonal_decompose(series_jan_2018)
fig = decomposition.plot()
plt.show()

print("\n")
print("*************************************************************************************ANALYSIS FOR 2019**************************************************************************")
print()
decomposition = sm.tsa.seasonal_decompose(series_jan_2019)
fig = decomposition.plot()
plt.show()

print("\n")
print("*************************************************************************************ANALYSIS FOR 2020**************************************************************************")
print()
decomposition = sm.tsa.seasonal_decompose(series_jan_2020)
fig = decomposition.plot()
plt.show()

print("\n")
print("*************************************************************************************ANALYSIS FOR 2021**************************************************************************")
print()
decomposition = sm.tsa.seasonal_decompose(series_jan_2021)
fig = decomposition.plot()
plt.show()
# Out:
# *************************************************************************************ANALYSIS FOR 2016**************************************************************************
# *************************************************************************************ANALYSIS FOR 2017**************************************************************************
# *************************************************************************************ANALYSIS FOR 2018**************************************************************************
# *************************************************************************************ANALYSIS FOR 2019**************************************************************************
# *************************************************************************************ANALYSIS FOR 2020**************************************************************************
# *************************************************************************************ANALYSIS FOR 2021**************************************************************************

# %%
#checking skews

# %%
Train.skew()
# Out:
# price    1.557813
# dtype: float64

# %%
#checking if log and square root solve the problem

# %%
Train_log = np.log(Train) #log transform
Train_log.skew()
# Out:
# price    1.315869
# dtype: float64

# %%
Train_sqrt = np.sqrt(Train) #square root transform
Train_sqrt.skew()
# Out:
# price    1.436822
# dtype: float64

# %%
#defining mean absolute percentage error

# %%
def mean_absolute_percentage_error(test, predictions): 
    test, predictions = np.array(test), np.array(predictions)
    return np.mean(np.abs((test - predictions) / test)) * 100

# %% [markdown]
# ### Data Transformation using Boxcox

# %%
#Doing boxcox transform

# %%
from scipy import stats
from scipy.special import boxcox, inv_boxcox

# %%
series = read_csv(r'C:\Users\prathikm\Documents\P111\Gold_data.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
dataframe = DataFrame(series.values)
dataframe.columns = ['price']
dataframe['price'] = stats.boxcox(dataframe['price'], lmbda=0.0)
plt.figure(1)
# line plot
plt.subplot(211)
plt.plot(dataframe['price'])
# histogram
plt.subplot(212)
plt.hist(dataframe['price'])
plt.show()

# %% [markdown]
# ### Train-Test Split for Model

# %%
#Again doing 80:20 Split
Train=dataframe.iloc[:1745,:]
Test=dataframe.iloc[1745:,]

# %% [markdown]
# ### Model Buidling & Evaluation (Selected Model: Holts winter exponential smoothing with additive seasonality and additive trend)

# %%
# Holts winter exponential smoothing with additive seasonality and additive trend
hwe_model_add_add = ExponentialSmoothing(Train["price"],seasonal="add",trend="add",seasonal_periods=365).fit() #add the trend to the model
pred_hwe_add_add = hwe_model_add_add.predict(start = Test.index[0],end = Test.index[-1])
mean_absolute_percentage_error(pred_hwe_add_add,Test.price)
# Out:
# 1.464501723667664

# %%
hwe_model_add_add = ExponentialSmoothing(dataframe["price"],seasonal="add",trend="add",seasonal_periods=365).fit()

# %% [markdown]
# ### Forecasting for next 30 days

# %%
Forecasted_price = hwe_model_add_add.forecast(30)
Forecasted_price
# Out:
# 2182    8.377303
# 2183    8.381368
# 2184    8.381694
# 2185    8.382596
# 2186    8.388206
# 2187    8.391305
# 2188    8.390212
# 2189    8.390604
# 2190    8.392281
# 2191    8.409352
# 2192    8.451921
# 2193    8.440034
# 2194    8.434283
# 2195    8.445856
# 2196    8.474408
# 2197    8.492107
# 2198    8.499794
# 2199    8.521255
# 2200    8.507746
# 2201    8.498881
# 2202    8.467972
# 2203    8.406962
# 2204    8.413809
# 2205    8.414775
# 2206    8.415063
# 2207    8.417089
# 2208    8.415282
# 2209    8.416324
# 2210    8.417501
# 2211    8.419644
# dtype: float64

# %% [markdown]
# ### Doing Inverse of Transform to get True Predictions

# %%
Forecasted_price_true = inv_boxcox(Forecasted_price, 0.0)
Forecasted_price_true
# Out:
# 2182    4347.267267
# 2183    4364.976628
# 2184    4366.398922
# 2185    4370.340246
# 2186    4394.928221
# 2187    4408.569287
# 2188    4403.750161
# 2189    4405.478715
# 2190    4412.872869
# 2191    4488.849688
# 2192    4684.063128
# 2193    4628.710988
# 2194    4602.171152
# 2195    4655.741640
# 2196    4790.587064
# 2197    4876.127718
# 2198    4913.756171
# 2199    5020.351222
# 2200    4952.987013
# 2201    4909.272223
# 2202    4759.852211
# 2203    4478.136293
# 2204    4508.900449
# 2205    4513.261744
# 2206    4514.561482
# 2207    4523.716424
# 2208    4515.548444
# 2209    4520.254818
# 2210    4525.579371
# 2211    4535.290863
# dtype: float64

# %% [markdown]
# ### Plotting predictions in graph

# %%
series_no_inx = series_2.reset_index()
series_no_inx
# Out:
#            date    price
# 0    2016-01-01  2252.60
# 1    2016-01-02  2454.50
# 2    2016-01-03  2708.10
# 3    2016-01-04  2577.80
# 4    2016-01-05  2597.75
# ...         ...      ...
# 2177 2021-12-17  4394.40
# 2178 2021-12-18  4389.50
# 2179 2021-12-19  4389.50
# 2180 2021-12-20  4354.10
# 2181 2021-12-21  4346.50
#
# [2182 rows x 2 columns]

# %%
Forecasted_price_true
# Out:
# 2182    4347.267267
# 2183    4364.976628
# 2184    4366.398922
# 2185    4370.340246
# 2186    4394.928221
# 2187    4408.569287
# 2188    4403.750161
# 2189    4405.478715
# 2190    4412.872869
# 2191    4488.849688
# 2192    4684.063128
# 2193    4628.710988
# 2194    4602.171152
# 2195    4655.741640
# 2196    4790.587064
# 2197    4876.127718
# 2198    4913.756171
# 2199    5020.351222
# 2200    4952.987013
# 2201    4909.272223
# 2202    4759.852211
# 2203    4478.136293
# 2204    4508.900449
# 2205    4513.261744
# 2206    4514.561482
# 2207    4523.716424
# 2208    4515.548444
# 2209    4520.254818
# 2210    4525.579371
# 2211    4535.290863
# dtype: float64

# %%
series_no_inx_dec = series_no_inx[2050:]
series_no_inx_dec
# Out:
#            date   price
# 2050 2021-08-12  4324.5
# 2051 2021-08-13  4236.0
# 2052 2021-08-14  4239.8
# 2053 2021-08-15  4239.8
# 2054 2021-08-16  4255.5
# ...         ...     ...
# 2177 2021-12-17  4394.4
# 2178 2021-12-18  4389.5
# 2179 2021-12-19  4389.5
# 2180 2021-12-20  4354.1
# 2181 2021-12-21  4346.5
#
# [132 rows x 2 columns]

# %%
series_no_inx_dec['price'].plot(figsize=(12,8),legend=True,label='Current Price [Showing only last 132 days for better view]')
Forecasted_price_true.plot(legend=True,label='Forecasted Price Price for 30-days')
plt.title('Gold Price Prediction');
